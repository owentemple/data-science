# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

movies = pd.read_csv('fandango_score_comparison.csv')

# %%
movies
# Out:
#                                                FILM  RottenTomatoes  \
# 0                    Avengers: Age of Ultron (2015)              74
# 1                                 Cinderella (2015)              85
# 2                                    Ant-Man (2015)              80
# 3                            Do You Believe? (2015)              18
# 4                     Hot Tub Time Machine 2 (2015)              14
# 5                          The Water Diviner (2015)              63
# 6                             Irrational Man (2015)              42
# 7                                   Top Five (2014)              86
# 8                      Shaun the Sheep Movie (2015)              99
# 9                               Love & Mercy (2015)              89
# 10                Far From The Madding Crowd (2015)              84
# 11                                 Black Sea (2015)              82
# 12                                 Leviathan (2014)              99
# ...

# %%
plt.hist(movies['Metacritic_norm_round'])
plt.xlim(0.0,5.0)
# Out:
# (0.0, 5.0)

# %%
plt.hist(movies['Fandango_Stars'])
plt.xlim(0.0,5.0)
# Out:
# (0.0, 5.0)

# %%
fd_mean = movies['Fandango_Stars'].mean()
mc_mean = movies['Metacritic_norm_round'].mean()

# %%
fd_mean
# Out:
# 4.0890410958904111

# %%
mc_mean
# Out:
# 2.9726027397260273

# %%
fd_median = movies['Fandango_Stars'].median()
mc_median = movies['Metacritic_norm_round'].median()

# %%
fd_median
# Out:
# 4.0

# %%
mc_median
# Out:
# 3.0

# %%
fd_stddev = np.std(movies['Fandango_Stars'])
mc_stddev = np.std(movies['Metacritic_norm_round'])

# %%
fd_stddev
# Out:
# 0.53853216126995307

# %%
mc_stddev
# Out:
# 0.98756102970386306

# %%
plt.scatter(movies['Fandango_Stars'],movies['Metacritic_norm_round'])
plt.xlabel('Fandango_Stars')
plt.ylabel('Metacritic_norm_round')

# %%
movies['fm_diff'] = (movies['Metacritic_norm_round'] - movies['Fandango_Stars'])

# %%
movies['fm_diff'] = np.absolute(movies['fm_diff'])

# %%
movies.sort_values(by='fm_diff',ascending=False).head(5)
# Out:
#                         FILM  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 3     Do You Believe? (2015)              18                   84          22
# 85         Little Boy (2015)              20                   81          30
# 47              Annie (2014)              27                   61          33
# 19             Pixels (2015)              17                   54          27
# 134  The Longest Ride (2015)              31                   73          33
#
#      Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# 3                4.7   5.4             5.0                   4.5     0.90
# 85               5.9   7.4             4.5                   4.3     1.00
# 47               4.8   5.2             4.5                   4.2     1.35
# 19               5.3   5.6             4.5                   4.1     0.85
# 134              4.8   7.2             4.5                   4.5     1.55
#
# ...

# %%
from scipy.stats import pearsonr, linregress

# %%
corr, pvalue = pearsonr(movies['Fandango_Stars'], movies['Metacritic_norm_round'])

# %%
corr
# Out:
# 0.17844919073895918

# %%
slope, intercept, rvalue, cc, pvalue = linregress(movies['Metacritic_norm_round'],movies['Fandango_Stars'])

# %%
pred_3 = 3 * slope + intercept

# %%
pred_3
# Out:
# 4.0917071528212041

# %%
print('y =',slope, ' * x ', '+ ',intercept)
# Out:
# y = 0.0973110779739  * x  +  3.7997739189

# %%
pred_1 = 1 * slope + intercept

# %%
pred_5 = 5 * slope + intercept

# %%
pred_1
# Out:
# 3.897084996873347

# %%
pred_5
# Out:
# 4.2863293087690604

# %%
plt.scatter(movies['Metacritic_norm_round'],movies['Fandango_Stars'])

# %%
xs = [1.0, 5.0]
ys = [pred_1, pred_5]
plt.scatter(movies['Metacritic_norm_round'],movies['Fandango_Stars'])
plt.plot(xs,ys)
plt.xlim(1,5)
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#           Timestamp Favorite programming language  \
# 0  4/8/2018 8:34:08                        Python
# 1  4/8/2018 9:57:15                        Python
# 2  4/8/2018 9:57:35                        Python
# 3  4/8/2018 9:57:58                        Python
# 4  4/8/2018 9:58:05                        Python
#
#           Favorite Monty Python movie  Years of Python experience  \
# 0        Monty Python's Life of Brian                        20.0
# 1     Monty Python and the Holy Grail                         4.0
# 2     Monty Python and the Holy Grail                         1.0
# 3     Monty Python and the Holy Grail                        12.0
# 4  Monty Python's The Meaning of Life                         7.0
#
#   Have used Scikit-learn  Age  \
# 0                   Yep!   53
# 1                   Yep!   33
# 2                   Yep!   31
# 3                   Yep!   60
# 4                   Yep!   48
#
# ...

# %%
df["How successful has this tutorial been so far?"].median()
# Out:
# 8.0

# %%
import numpy as np

# %%
df['Successful'] = np.where(df["How successful has this tutorial been so far?"]<8,0,1)

# %%
df['Successful']
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
# 5      1
# 6      0
# 7      0
# 8      1
# 9      0
# 10     0
# 11     0
# 12     0
# 13     0
# 14     0
# 15     1
# 16     1
# 17     1
# 18     1
# 19     0
# 20     1
# 21     1
# 22     0
# 23     1
# 24     1
# 25     1
# 26     1
# 27     1
# 28     1
# 29     1
#       ..
# 77     0
# 78     1
# 79     1
# 80     1
# 81     0
# 82     1
# 83     0
# 84     1
# 85     0
# 86     0
# 87     0
# 88     1
# 89     0
# 90     1
# 91     1
# 92     1
# 93     1
# 94     0
# 95     0
# 96     1
# 97     0
# 98     0
# 99     1
# 100    0
# 101    0
# 102    0
# 103    1
# 104    1
# 105    1
# 106    0
# Name: Successful, Length: 107, dtype: int64

# %%
df.columns
# Out:
# Index(['Timestamp', 'Favorite programming language',
#        'Favorite Monty Python movie', 'Years of Python experience',
#        'Have used Scikit-learn', 'Age',
#        'In the Terminator franchise, did you root for the humans or the machines?',
#        'Which is the better game?',
#        'Years of post-secondary education (e.g. BA=4; Ph.D.=10)',
#        'How successful has this tutorial been so far?', 'Successful'],
#       dtype='object')

# %%
df_dummies = pd.get_dummies(df[['Favorite programming language',
       'Favorite Monty Python movie', 'Years of Python experience',
       'Have used Scikit-learn', 'Age',
       'In the Terminator franchise, did you root for the humans or the machines?',
       'Which is the better game?']])

# %%
df_dummies.head()
# Out:
#    Years of Python experience  Age  Favorite programming language_C++  \
# 0                        20.0   53                                  0
# 1                         4.0   33                                  0
# 2                         1.0   31                                  0
# 3                        12.0   60                                  0
# 4                         7.0   48                                  0
#
#    Favorite programming language_JavaScript  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
#    Favorite programming language_MATLAP  Favorite programming language_Python  \
# 0                                     0                                     1
# 1                                     0                                     1
# ...
